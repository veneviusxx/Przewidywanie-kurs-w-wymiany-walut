# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
file_path = r'C:\Users\justy\Desktop\Dane_usdeur\usdeur_przedpandemia.csv'
przedpandemia = pd.read_csv(file_path)
przedpandemia.drop(['Adj Close', 'Volume'], axis=1)
# Out:
#            Date     Open     High      Low    Close
# 0    2017-01-02  0.94960  0.95550  0.94870  0.94994
# 1    2017-01-03  0.95610  0.96640  0.95310  0.95602
# 2    2017-01-04  0.95984  0.96234  0.95430  0.95970
# 3    2017-01-05  0.95250  0.95360  0.94260  0.95230
# 4    2017-01-06  0.94290  0.94880  0.94260  0.94287
# ..          ...      ...      ...      ...      ...
# 755  2019-11-25  0.90710  0.90858  0.90630  0.90723
# 756  2019-11-26  0.90810  0.90843  0.90690  0.90790
# 757  2019-11-27  0.90727  0.90964  0.90727  0.90723
# 758  2019-11-28  0.90859  0.90896  0.90750  0.90869
# 759  2019-11-29  0.90816  0.91051  0.90689  0.90812
#
# [760 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Wczytanie danych z pliku CSV
file_path = r'C:\Users\justy\Desktop\Dane_usdeur\usdeur_przedpandemia.csv'
przedpandemia = pd.read_csv(file_path)

# Konwersja kolumny 'Date' na typ daty
przedpandemia['Date'] = pd.to_datetime(przedpandemia['Date'])

# Zmiana nazwy kolumny 'Close*' na 'Close'
przedpandemia.rename(columns={'Close*': 'Close'}, inplace=True)

# Wykresy czasowe
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Close', data=przedpandemia)
plt.title('USD/EUR - Wykres czasowy')
plt.xlabel('Data')
plt.ylabel('Kurs USD/EUR')

# Zapisz pierwszy wykres
plt.savefig('wykres_czasowy.png')
plt.close()

# Histogram
plt.figure(figsize=(12, 6))
sns.histplot(przedpandemia['Close'], kde=True)
plt.title('USD/EUR - Histogram')
plt.xlabel('Kurs USD/EUR')
plt.ylabel('Liczba obserwacji')

# Zapisz drugi wykres
plt.savefig('histogram.png')
plt.close()

# Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=przedpandemia['Date'].dt.year, y=przedpandemia['Close'])
plt.title('USD/EUR - Boxploty dla poszczególnych lat')
plt.xlabel('Rok')
plt.ylabel('Kurs USD/EUR')

# Zapisz trzeci wykres
#plt.savefig('boxploty.png')
#plt.close()
plt.show()

# %%
# Wczytanie danych z pliku CSV
file_path_wtrakciepandemii = r'C:\Users\justy\Desktop\Dane_usdeur\usdeur_wtrakciepandemii.csv'
wtrakciepandemii = pd.read_csv(file_path_wtrakciepandemii)

# Konwersja kolumny 'Date' na typ daty
wtrakciepandemii['Date'] = pd.to_datetime(wtrakciepandemii['Date'])

# Zmiana nazwy kolumny 'Close*' na 'Close'
wtrakciepandemii.rename(columns={'Close*': 'Close'}, inplace=True)

# Wykresy czasowe
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Close', data=wtrakciepandemii, color='purple')
plt.title('USD/EUR - Wykres czasowy (W trakcie pandemii)')
plt.xlabel('Data')
plt.ylabel('Kurs USD/EUR')
plt.show()

# Histogram
plt.figure(figsize=(12, 6))
sns.histplot(wtrakciepandemii['Close'], kde=True, color='purple')
plt.title('USD/EUR - Histogram (W trakcie pandemii)')
plt.xlabel('Kurs USD/EUR')
plt.ylabel('Liczba obserwacji')
plt.show()

# Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=wtrakciepandemii['Date'].dt.year, y=wtrakciepandemii['Close'], color='purple')
plt.title('USD/EUR - Boxploty dla poszczególnych lat (W trakcie pandemii)')
plt.xlabel('Rok')
plt.ylabel('Kurs USD/EUR')
plt.show()

# %%
# Wczytanie danych z pliku CSV
file_path_odwojny = r'C:\Users\justy\Desktop\Dane_usdeur\usdeur_odwojny.csv'
odwojny = pd.read_csv(file_path_odwojny)

# Konwersja kolumny 'Date' na typ daty
odwojny['Date'] = pd.to_datetime(odwojny['Date'])

# Zmiana nazwy kolumny 'Close*' na 'Close'
odwojny.rename(columns={'Close*': 'Close'}, inplace=True)

# Wykresy czasowe
plt.figure(figsize=(12, 6))
sns.lineplot(x='Date', y='Close', data=odwojny, color='#FF8C00')
plt.title('USD/EUR - Wykres czasowy (Od wojny)')
plt.xlabel('Data')
plt.ylabel('Kurs USD/EUR')
plt.show()

# Histogram
plt.figure(figsize=(12, 6))
sns.histplot(odwojny['Close'], kde=True, color='#FF8C00')
plt.title('USD/EUR - Histogram (Od wojny)')
plt.xlabel('Kurs USD/EUR')
plt.ylabel('Liczba obserwacji')
plt.show()

# Boxplot
plt.figure(figsize=(12, 6))
sns.boxplot(x=odwojny['Date'].dt.year, y=odwojny['Close'], color='#FF8C00')
plt.title('USD/EUR - Boxploty dla poszczególnych lat (Od wojny)')
plt.xlabel('Rok')
plt.ylabel('Kurs USD/EUR')
plt.show()

# %%
# Wyznaczanie różnych wskaźników dla przedpandemii
srednia_przedpandemia = przedpandemia['Close'].mean()
mediana_przedpandemia = przedpandemia['Close'].median()
odchylenie_std_przedpandemia = przedpandemia['Close'].std()
wariancja_przedpandemia = przedpandemia['Close'].var()
q1_przedpandemia = przedpandemia['Close'].quantile(0.25)
q3_przedpandemia = przedpandemia['Close'].quantile(0.75)
iqr_przedpandemia = q3_przedpandemia - q1_przedpandemia
kurtoza_przedpandemia = przedpandemia['Close'].kurtosis()
skosnosc_przedpandemia = przedpandemia['Close'].skew()
min_przedpandemia = przedpandemia['Close'].min()
max_przedpandemia = przedpandemia['Close'].max()

# Tworzenie DataFrame tylko dla okresu przedpandemii
data_przedpandemia = {
    'Wskaźnik': ['Średnia', 'Mediana', 'Odchylenie standardowe', 'Wariancja', 'Q1', 'Q3', 'IQR', 'Kurtoza', 'Skośność', 'Min', 'Max'],
    'Wartość': [srednia_przedpandemia, mediana_przedpandemia, odchylenie_std_przedpandemia, wariancja_przedpandemia, q1_przedpandemia, q3_przedpandemia, iqr_przedpandemia, kurtoza_przedpandemia, skosnosc_przedpandemia, min_przedpandemia, max_przedpandemia]
}

df_przedpandemia = pd.DataFrame(data_przedpandemia)

# Wyświetlanie wyników
print(df_przedpandemia)
# Out:
#                   Wskaźnik   Wartość
# 0                  Średnia  0.875145
# 1                  Mediana  0.878090
# 2   Odchylenie standardowe  0.035316
# 3                Wariancja  0.001247
# 4                       Q1  0.850560
# 5                       Q3  0.896580
# 6                      IQR  0.046020
# 7                  Kurtoza -0.417429
# 8                 Skośność  0.020752
# 9                      Min  0.799360
# 10                     Max  0.959700

# %%
# Wyznaczanie różnych wskaźników
srednia_wtrakciepandemii = wtrakciepandemii['Close'].mean()
mediana_wtrakciepandemii = wtrakciepandemii['Close'].median()
odchylenie_std_wtrakciepandemii = wtrakciepandemii['Close'].std()
wariancja_wtrakciepandemii = wtrakciepandemii['Close'].var()
q1_wtrakciepandemii = wtrakciepandemii['Close'].quantile(0.25)
q3_wtrakciepandemii = wtrakciepandemii['Close'].quantile(0.75)
iqr_wtrakciepandemii = q3_wtrakciepandemii - q1_wtrakciepandemii
kurtoza_wtrakciepandemii = wtrakciepandemii['Close'].kurtosis()
skosnosc_wtrakciepandemii = wtrakciepandemii['Close'].skew()

# Wyświetlanie wyników
print(f"Średnia_wtrakciepandemii: {srednia_wtrakciepandemii}")
print(f"Mediana_wtrakciepandemii: {mediana_wtrakciepandemii}")
print(f"Odchylenie standardowe_wtrakciepandemii: {odchylenie_std_wtrakciepandemii}")
print(f"Wariancja_wtrakciepandemii: {wariancja_wtrakciepandemii}")
print(f"Q1_wtrakciepandemii: {q1_wtrakciepandemii}")
print(f"Q3_wtrakciepandemii: {q3_wtrakciepandemii}")
print(f"IQR_wtrakciepandemii: {iqr_wtrakciepandemii}")
print(f"Kurtoza_wtrakciepandemii: {kurtoza_wtrakciepandemii}")
print(f"Skośność_wtrakciepandemii: {skosnosc_wtrakciepandemii}")
# Out:
# Średnia_wtrakciepandemii: 0.8629520550458716
# Mediana_wtrakciepandemii: 0.851651
# Odchylenie standardowe_wtrakciepandemii: 0.03236783855963663
# Wariancja_wtrakciepandemii: 0.0010476769730227002
# Q1_wtrakciepandemii: 0.83923
# Q3_wtrakciepandemii: 0.89
# IQR_wtrakciepandemii: 0.05076999999999998
# Kurtoza_wtrakciepandemii: -1.0182521158987148
# Skośność_wtrakciepandemii: 0.4511164928040198

# %%
# Wyznaczanie różnych wskaźników
srednia_odwojny = odwojny['Close'].mean()
mediana_odwojny = odwojny['Close'].median()
odchylenie_std_odwojny = odwojny['Close'].std()
wariancja_odwojny = odwojny['Close'].var()
q1_odwojny = odwojny['Close'].quantile(0.25)
q3_odwojny = odwojny['Close'].quantile(0.75)
iqr_odwojny = q3_odwojny - q1_odwojny
kurtoza_odwojny = odwojny['Close'].kurtosis()
skosnosc_odwojny = odwojny['Close'].skew()

# Wyświetlanie wyników
print(f"Średnia_odwojny: {srednia_odwojny}")
print(f"Mediana_odwojny: {mediana_odwojny}")
print(f"Odchylenie standardowe_odwojny: {odchylenie_std_odwojny}")
print(f"Wariancja_odwojny: {wariancja_odwojny}")
print(f"Q1_odwojny: {q1_odwojny}")
print(f"Q3_odwojny: {q3_odwojny}")
print(f"IQR_odwojny: {iqr_odwojny}")
print(f"Kurtoza_odwojny: {kurtoza_odwojny}")
print(f"Skośność_odwojny: {skosnosc_odwojny}")
# Out:
# Średnia_odwojny: 0.9444513501144164
# Mediana_odwojny: 0.93615
# Odchylenie standardowe_odwojny: 0.03413264241483336
# Wariancja_odwojny: 0.0011650372782188814
# Q1_odwojny: 0.91929
# Q3_odwojny: 0.9592
# IQR_odwojny: 0.03991
# Kurtoza_odwojny: -0.047030739061207694
# Skośność_odwojny: 0.8702295106144782
